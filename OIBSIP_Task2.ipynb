# %% [markdown]
# ## Importing the Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# %% [markdown]
# ## Data Collection and Processing

# %%
# Loading and reading the dataset
df = pd.read_csv(r'C:\Users\USER\Documents\car data analysis\car data.csv', encoding= 'unicode_escape')

# %%
# inspecting the first 5 rows of the dataframe
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
# checking the number of rows and columns
df.shape
# Out:
# (301, 9)

# %%
# checking the number of missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# getting some information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# checking the distribution of categorical data
print(df.Fuel_Type.value_counts())
print(df.Selling_type.value_counts())
print(df.Transmission.value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        195
# Individual    106
# Name: Selling_type, dtype: int64
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %% [markdown]
# ## Encoding the Categorical Data

# %%
# encoding "Fuel_Type" Column
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# encoding "Seller_Type" Column
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %% [markdown]
# ## Splitting the data and Target

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
Y = df['Selling_Price']

# %%
print(X)
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [301 rows x 7 columns]

# %%
print(Y)
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# ## Splitting Training and Test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=2)

# %% [markdown]
# ## Model Training

# %%
# loading the linear regression model
lin_reg_model = LinearRegression()

# %%
lin_reg_model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Model Evaluation

# %%
# prediction on Training data
training_data_prediction = lin_reg_model.predict(X_train)

# %%
# R squared Error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.8796483009370215

# %% [markdown]
# ## Visualize the actual prices and Predicted prices

# %%
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# prediction on Training data
test_data_prediction = lin_reg_model.predict(X_test)

# %%
# prediction on Training data
test_data_prediction = lin_reg_model.predict(X_test)

# %%
plt.scatter(Y_test, test_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# loading the linear regression model
lass_reg_model = Lasso()

# %%
lass_reg_model.fit(X_train,Y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# prediction on Training data
training_data_prediction = lass_reg_model.predict(X_train)

# %%
# R squared Error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.842448071824074

# %% [markdown]
# ## Visualize the actual prices and Predicted prices

# %%
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# prediction on Training data
test_data_prediction = lass_reg_model.predict(X_test)

# %%
# R squared Error
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.8709763132343395

# %%
plt.scatter(Y_test, test_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
conda uninstall pandas
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - pandas

# %%
conda install -c conda-forge pandas=0.24
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\USER\Anaconda3
#
#   added / updated specs:
#     - pandas=0.24
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       h56e8100_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     matplotlib-base-3.2.2      |   py37hab8957c_1         7.0 MB  conda-forge
#     mkl_fft-1.0.14             |   py37h6288b17_0         155 KB
#     mkl_random-1.0.4           |   py37h343c172_0         287 KB
#     numpy-1.17.0               |   py37h19fb1c0_0          25 KB
#     numpy-base-1.17.0          |   py37hc3f5095_0         4.8 MB
#     openssl-1.1.1l             |       h8ffe710_0         5.7 MB  conda-forge
#     pandas-0.24.0              |   py37h6538335_0         9.4 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     seaborn-0.10.1             |             py_0         158 KB  conda-forge
#     tensorboard-1.14.0         |           py37_0         3.2 MB  conda-forge
#     tensorflow-1.14.0          |       h1f41ff6_0          23 KB  conda-forge
#     tensorflow-base-1.14.0     |   py37hc8dfbb8_0        57.3 MB  conda-forge
#     tensorflow-estimator-1.14.0|   py37h5ca1d4c_0         646 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        89.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.2.2-py37hab8957c_1
#   numpy-base         pkgs/r/win-64::numpy-base-1.17.0-py37hc3f5095_0
#   pandas             conda-forge/win-64::pandas-0.24.0-py37h6538335_0
#   python_abi         conda-forge/win-64::python_abi-3.7-2_cp37m
#   seaborn            conda-forge/noarch::seaborn-0.10.1-py_0
#   tensorboard        conda-forge/win-64::tensorboard-1.14.0-py37_0
#   tensorflow-base    conda-forge/win-64::tensorflow-base-1.14.0-py37hc8dfbb8_0
#   tensorflow-estima~ conda-forge/win-64::tensorflow-estimator-1.14.0-py37h5ca1d4c_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.7.22-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#   mkl_fft            pkgs/main::mkl_fft-1.0.12-py37h14836f~ --> pkgs/r::mkl_fft-1.0.14-py37h6288b17_0
#   mkl_random         pkgs/main::mkl_random-1.0.2-py37h343c~ --> pkgs/r::mkl_random-1.0.4-py37h343c172_0
#   numpy              pkgs/main::numpy-1.16.4-py37h19fb1c0_0 --> pkgs/r::numpy-1.17.0-py37h19fb1c0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl              pkgs/main::openssl-1.1.1t-h2bbff1b_0 --> conda-forge::openssl-1.1.1l-h8ffe710_0
#   tensorflow         pkgs/main::tensorflow-1.14.0-gpu_py37~ --> conda-forge::tensorflow-1.14.0-h1f41ff6_0
#
#
#
# Downloading and Extracting Packages
#
# mkl_random-1.0.4     | 287 KB    |            |   0%
#
# matplotlib-base-3.2. | 7.0 MB    |            |   0%
#
#
# numpy-base-1.17.0    | 4.8 MB    |            |   0%
#
#
#
# openssl-1.1.1l       | 5.7 MB    |            |   0%
#
#
#
#
# seaborn-0.10.1       | 158 KB    |            |   0%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    |            |   0%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    |            |   0%
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 146 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# google-pasta-0.2.0   | 42 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.0.14       | 155 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.17.0         | 25 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-1.14.0    | 23 KB     |            |   0%
#
#
# numpy-base-1.17.0    | 4.8 MB    |            |   0%
#
#
#
# openssl-1.1.1l       | 5.7 MB    |            |   0%
#
#
# numpy-base-1.17.0    | 4.8 MB    | #          |  10%
#
#
#
#
# seaborn-0.10.1       | 158 KB    | #          |  10%
#
#
# numpy-base-1.17.0    | 4.8 MB    | ##         |  20%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | 6          |   6%
#
# matplotlib-base-3.2. | 7.0 MB    |            |   0%
#
#
# numpy-base-1.17.0    | 4.8 MB    | ###5       |  35%
#
#
#
#
# seaborn-0.10.1       | 158 KB    | ########## | 100%
#
#
#
#
# seaborn-0.10.1       | 158 KB    | ########## | 100%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | #5         |  15%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    |            |   0%
#
# matplotlib-base-3.2. | 7.0 MB    | 2          |   3%
# mkl_random-1.0.4     | 287 KB    | 5          |   6%
#
#
# numpy-base-1.17.0    | 4.8 MB    | ####3      |  43%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ##         |  21%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | 3          |   4%
#
# matplotlib-base-3.2. | 7.0 MB    | 5          |   6%
# mkl_random-1.0.4     | 287 KB    | ####4      |  45%
#
#
# numpy-base-1.17.0    | 4.8 MB    | #####      |  50%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ##4        |  24%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | 5          |   5%
#
#
# numpy-base-1.17.0    | 4.8 MB    | #####7     |  58%
# mkl_random-1.0.4     | 287 KB    | #####5     |  56%
#
# matplotlib-base-3.2. | 7.0 MB    | 7          |   7%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ###        |  31%
#
#
# numpy-base-1.17.0    | 4.8 MB    | ######3    |  63%
# mkl_random-1.0.4     | 287 KB    | ######6    |  67%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | 6          |   7%
#
# matplotlib-base-3.2. | 7.0 MB    | #          |  11%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ###6       |  37%
#
#
# numpy-base-1.17.0    | 4.8 MB    | #######9   |  80%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #1         |  12%
#
# matplotlib-base-3.2. | 7.0 MB    | #9         |  19%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ####9      |  49%
# mkl_random-1.0.4     | 287 KB    | ########## | 100%
# mkl_random-1.0.4     | 287 KB    | ########## | 100%
#
#
# numpy-base-1.17.0    | 4.8 MB    | #########4 |  95%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #5         |  16%
#
# matplotlib-base-3.2. | 7.0 MB    | ##2        |  23%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | #####5     |  56%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ##         |  20%
#
# matplotlib-base-3.2. | 7.0 MB    | ##6        |  26%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ######3    |  63%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ##5        |  25%
#
# matplotlib-base-3.2. | 7.0 MB    | ##9        |  30%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | #######    |  70%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ##9        |  30%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | 2          |   2%
#
# matplotlib-base-3.2. | 7.0 MB    | ###3       |  34%
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      | ########## | 100%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | #######7   |  77%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ###4       |  34%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | ###7       |  37%
#
# matplotlib-base-3.2. | 7.0 MB    | ###7       |  37%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | #####9     |  59%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ########3  |  84%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   |            |   0%
#
# matplotlib-base-3.2. | 7.0 MB    | ####       |  40%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ########9  |  89%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ####2      |  43%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | #######9   |  79%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   |            |   0%
#
# matplotlib-base-3.2. | 7.0 MB    | ####3      |  43%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | #########8 |  98%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ####8      |  48%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   |            |   1%
#
# matplotlib-base-3.2. | 7.0 MB    | #####      |  51%
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 146 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
# google-pasta-0.2.0   | 42 KB     | ###7       |  38%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #####6     |  57%
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 146 KB    | ######5    |  66%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 1          |   1%
#
# matplotlib-base-3.2. | 7.0 MB    | #####5     |  55%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ######2    |  62%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 2          |   2%
#
# matplotlib-base-3.2. | 7.0 MB    | #####9     |  59%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | #          |  11%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #######2   |  73%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 2          |   3%
#
# matplotlib-base-3.2. | 7.0 MB    | ######3    |  64%
#
# matplotlib-base-3.2. | 7.0 MB    | ######8    |  68%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 3          |   4%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #######7   |  78%
#
# matplotlib-base-3.2. | 7.0 MB    | #######2   |  72%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 4          |   4%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | ###1       |  32%
#
# matplotlib-base-3.2. | 7.0 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 5          |   6%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ########9  |  90%
#
# matplotlib-base-3.2. | 7.0 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 6          |   6%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #########4 |  94%
#
# matplotlib-base-3.2. | 7.0 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 7          |   7%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | #########8 |  99%
#
# matplotlib-base-3.2. | 7.0 MB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.0.14       | 155 KB    | #          |  10%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 8          |   8%
#
# matplotlib-base-3.2. | 7.0 MB    | #########5 |  95%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-1.14.0    | 23 KB     | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    |            |   0%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | 9          |  10%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.17.0         | 25 KB     | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    | ######5    |  65%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #2         |  13%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #3         |  13%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #3         |  14%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #4         |  15%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #5         |  15%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #5         |  16%
#
#
# numpy-base-1.17.0    | 4.8 MB    | ########## | 100%
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #6         |  17%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #7         |  18%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #8         |  19%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##         |  20%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##3        |  24%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##5        |  26%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ###9       |  39%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #####7     |  57%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ######1    |  61%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ######5    |  65%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | ########## | 100%
#
#
#
#
#
#
# tensorflow-estimator | 646 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ######9    |  69%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #######1   |  71%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ########   |  81%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #########  |  90%
#
#
#
# openssl-1.1.1l       | 5.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #########2 |  93%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
# google-pasta-0.2.0   | 42 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# google-pasta-0.2.0   | 42 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 146 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 146 KB    | ########## | 100%
#
#
#
#
#
# pandas-0.24.0        | 9.4 MB    | ########## | 100%
#
# matplotlib-base-3.2. | 7.0 MB    | ########## | 100%
#
# matplotlib-base-3.2. | 7.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.0.14       | 155 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.0.14       | 155 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 150 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-1.14.0    | 23 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-1.14.0    | 23 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.17.0         | 25 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.17.0         | 25 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-1.14.0   | 3.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# tensorflow-base-1.14 | 57.3 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==custom=py37_1
#   - defaults/win-64::astropy==3.2.1=py37he774522_0
#   - defaults/win-64::bkcharts==0.2=py37_0
#   - defaults/win-64::blaze==0.11.3=py37_0
#   - defaults/win-64::bokeh==1.2.0=py37_0
#   - defaults/win-64::bottleneck==1.2.1=py37h452e1ab_1
#   - defaults/noarch::dask==2.1.0=py_0
#   - defaults/win-64::datashape==0.5.4=py37haa95532_1
#   - defaults/win-64::h5py==2.9.0=py37h5e291fa_0
#   - defaults/win-64::imageio==2.5.0=py37_0
#   - defaults/win-64::keras==2.3.1=0
#   - defaults/noarch::keras-applications==1.0.8=py_1
#   - defaults/win-64::keras-base==2.3.1=py37_0
#   - defaults/win-64::keras-gpu==2.3.1=0
#   - defaults/noarch::keras-preprocessing==1.1.2=pyhd3eb1b0_0
#   - defaults/win-64::matplotlib==3.1.0=py37hc8f65d3_0
#   - defaults/win-64::mkl-service==2.0.2=py37he774522_0
#   - defaults/win-64::mkl_fft==1.0.12=py37h14836fe_0
#   - defaults/win-64::mkl_random==1.0.2=py37h343c172_0
#   - defaults/win-64::numba==0.44.1=py37hf9181ef_0
#   - defaults/win-64::numexpr==2.6.9=py37hdce8814_0
#   - defaults/win-64::numpy==1.16.4=py37h19fb1c0_0
#   - defaults/win-64::odo==0.5.1=py37_0
#   - defaults/win-64::patsy==0.5.1=py37_0
#   - defaults/win-64::pytables==3.5.2=py37h1da0976_1
#   - defaults/win-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/win-64::pytest-astropy==0.5.0=py37_0
#   - defaults/win-64::pytest-doctestplus==0.3.0=py37_0
#   - defaults/win-64::pywavelets==1.0.3=py37h8c2d366_1
#   - defaults/win-64::scikit-image==0.15.0=py37ha925a31_0
#   - defaults/win-64::scikit-learn==0.21.2=py37h6288b17_0
#   - defaults/win-64::scipy==1.2.1=py37h29ff71c_0
#   - defaults/win-64::statsmodels==0.10.0=py37h8c2d366_0
#   - defaults/win-64::tensorflow==1.14.0=gpu_py37h5512b17_0
#   - defaults/win-64::tensorflow-gpu==1.14.0=h0d30ee6_0
#   - defaults/win-64::_anaconda_depends==5.3.1=py37_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0
#
#
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(141): Could not remove or rename C:\Users\USER\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf.  Please remove this file manually (you may need to reboot to free file handles)
